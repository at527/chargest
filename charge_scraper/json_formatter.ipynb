# %%
import json

car_data = {}
with open('charge_times.json') as f:
    car_data = json.load(f)

# %%
pretty_json = json.dumps(car_data, indent=2, separators=(',', ':'))
print(pretty_json)
# Out:
# {
#   "Acura":{
#     "Acura ZDX":{
#       "Acura ZDX Type S":[
#         0,
#         70,
#         129,
#         181,
#         226,
#         267,
#         304,
#         337,
#         368,
#         397,
#         424,
#         449,
#         474,
#         499,
#         524,
#         548,
#         571,
#         595,
#         618,
#         641,
#         663,
#         685,
#         707,
#         729,
#         750,
#         771,
#         792,
#         813,
#         834,
#         855,
#         876,
#         898,
#         919,
#         940,
#         962,
#         984,
#         1006,
#         1028,
#         1052,
#         1075,
#         1100,
#         1124,
#         1150,
#         1176,
#         1203,
#         1230,
#         1257,
#         1285,
#         1313,
#         1341,
#         1370,
#         1399,
#         1428,
#         1457,
#         1486,
#         1515,
#         1544,
#         1573,
#         1602,
#         1631,
# ...

# %%
import pprint

pp = pprint.PrettyPrinter(indent=2, width=1000)
formatted = pp.pformat(car_data)
print(formatted)
test_deserialize = json.dumps(formatted)
test_deserialize
# Out:
# { 'Acura': {'Acura ZDX': {'Acura ZDX Type S': [0, 70, 129, 181, 226, 267, 304, 337, 368, 397, 424, 449, 474, 499, 524, 548, 571, 595, 618, 641, 663, 685, 707, 729, 750, 771, 792, 813, 834, 855, 876, 898, 919, 940, 962, 984, 1006, 1028, 1052, 1075, 1100, 1124, 1150, 1176, 1203, 1230, 1257, 1285, 1313, 1341, 1370, 1399, 1428, 1457, 1486, 1515, 1544, 1573, 1602, 1631, 1660, 1690, 1719, 1748, 1778, 1808, 1838, 1869, 1901, 1933, 1965, 1998, 2031, 2065, 2100, 2135, 2171, 2207, 2244, 2282, 2320, 2374, 2464, 2559, 2660, 2768, 2883, 3007, 3140, 3285, 3444, 3620, 3816, 4039, 4296, 4599, 4970, 5447, 6115, 7227, 10566]}},
# ...
